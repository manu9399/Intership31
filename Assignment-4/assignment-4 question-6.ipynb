# %%
import selenium
import pandas as pd 
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests
import re

# %%
driver=webdriver.Chrome(r"F:\flip robo\chromedriver.exe")

# %%
driver.get("https://www.billboard.com/")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[3]/div/nav/ul/li[1]")
search.click()

# %%
#empty lists
Song_name =[]
Artist_name =[]
Lastweek_rank =[]
Peak_rank =[]
Weekson_board =[]

# %%
#scraping song name
name_tags=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // lrv-u-flex-grow-1 lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-padding-l-050 lrv-u-padding-l-1@mobile-max"]')
for i in name_tags[0:100]:
    name=i.text
    Song_name.append(name)

# %%
Song_name
# Out:
# ['Bad Habit\nSteve Lacy',
#  'I Like You (A Happier Song)\nPost Malone Featuring Doja Cat',
#  'Sunroof\nNicky Youre & dazy',
#  'Super Freaky Girl\nNicki Minaj',
#  'You Proof\nMorgan Wallen',
#  "I Ain't Worried\nOneRepublic",
#  'The Kind Of Love We Make\nLuke Combs',
#  'About Damn Time\nLizzo',
#  'Wait For U\nFuture Featuring Drake & Tems',
#  'Late Night Talking\nHarry Styles',
#  'Me Porto Bonito\nBad Bunny & Chencho Corleone',
#  'Titi Me Pregunto\nBad Bunny',
#  'Vegas\nDoja Cat',
#  'Wasted On You\nMorgan Wallen',
#  'She Had Me At Heads Carolina\nCole Swindell',
#  'Heat Waves\nGlass Animals',
#  'Jimmy Cooks\nDrake Featuring 21 Savage',
#  'Running Up That Hill (A Deal With God)\nKate Bush',
#  'First Class\nJack Harlow',
#  'Something In The Orange\nZach Bryan',
#  '5 Foot 9\nTyler Hubbard',
#  'Stay\nThe Kid LAROI & Justin Bieber',
#  "I'm Good (Blue)\nDavid Guetta & Bebe Rexha",
#  'Shut Down\nBLACKPINK',
#  'Break My Soul\nBeyonce',
#  'Glimpse Of Us\nJoji',
# ...

# %%
#scarping artist name
name_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
for i in name_tags[0:100]:
    name=i.text
    Artist_name.append(name)

# %%
Artist_name
# Out:
# ['Steve Lacy',
#  'Post Malone Featuring Doja Cat',
#  'Nicky Youre & dazy',
#  'Nicki Minaj',
#  'Morgan Wallen',
#  'OneRepublic',
#  'Luke Combs',
#  'Lizzo',
#  'Future Featuring Drake & Tems',
#  'Harry Styles',
#  'Bad Bunny & Chencho Corleone',
#  'Bad Bunny',
#  'Doja Cat',
#  'Morgan Wallen',
#  'Cole Swindell',
#  'Glass Animals',
#  'Drake Featuring 21 Savage',
#  'Kate Bush',
#  'Jack Harlow',
#  'Zach Bryan',
#  'Tyler Hubbard',
#  'The Kid LAROI & Justin Bieber',
#  'David Guetta & Bebe Rexha',
#  'BLACKPINK',
#  'Beyonce',
#  'Joji',
#  'Elton John & Britney Spears',
#  'Chris Brown',
#  'Kane Brown With Katelyn Brown',
#  'Bad Bunny',
#  'Bailey Zimmerman',
#  'Yung Gravy',
#  'd4vd',
#  'Lil Baby',
#  'Justin Bieber',
#  'Bailey Zimmerman',
#  'Sia',
#  'Jelly Roll',
#  'Latto',
#  'Jon Pardi',
#  'DJ Khaled Featuring Drake & Lil Baby',
#  'Hitkidd & GloRilla',
#  'Charlie Puth Featuring Jung Kook',
#  'Marshmello & Khalid',
#  'The Weeknd',
#  'Bad Bunny',
# ...

# %%
#scraping Lastweek rank


rank_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]')
for i in rank_tags[0:100]:
    rank=i.text
    Lastweek_rank.append(rank)

# %%
Lastweek_rank
# Out:
# ['2',
#  '2',
#  '12',
#  '',
#  '',
#  '',
#  '5',
#  '3',
#  '16',
#  '',
#  '',
#  '',
#  '4',
#  '4',
#  '17',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '6',
#  '',
#  '',
#  '',
#  '6',
#  '6',
#  '19',
#  '',
#  '',
#  '',
#  '8',
#  '7',
#  '15',
#  '',
#  '',
#  '',
#  '14',
#  '8',
#  '14',
#  '',
#  '',
#  '',
#  '7',
#  '1',
#  '23',
#  '',
#  '',
#  '',
#  '10',
#  '1',
#  '21',
#  '',
#  '',
#  '',
#  '9',
#  '3',
#  '18',
#  '',
#  '',
#  '',
#  '11',
#  '6',
#  '20',
#  '',
#  '',
#  '',
#  '13',
#  '5',
#  '20',
#  '',
#  '',
#  '',
#  '15',
#  '14',
#  '16',
#  '',
#  '',
#  '',
#  '16',
#  '9',
#  '45',
#  '',
#  '',
#  '',
#  '18',
#  '16',
#  '17',
#  '',
#  '',
#  '',
#  '17',
#  '1',
#  '88',
#  '',
#  '',
#  '',
#  '20',
#  '1',
#  '14',
#  '']

# %%
#scraping peak rank


rank_tags=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max"]')
for i in rank_tags[0:100]:
    rank=i.text
    Peak_rank.append(rank)

# %%
Peak_rank
# Out:
# ['',
#  '1',
#  '',
#  '2',
#  '',
#  '3',
#  '',
#  '4',
#  '',
#  '1',
#  '',
#  '6',
#  '',
#  '7',
#  '',
#  '8',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '3',
#  '',
#  '6',
#  '',
#  '5',
#  '',
#  '14',
#  '',
#  '9',
#  '',
#  '16',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '3',
#  '',
#  '1',
#  '',
#  '21',
#  '',
#  '22',
#  '',
#  '1',
#  '',
#  '24',
#  '',
#  '25',
#  '',
#  '1',
#  '',
#  '8',
#  '',
#  '6',
#  '',
#  '29',
#  '',
#  '22',
#  '',
#  '4',
#  '',
#  '31',
#  '',
#  '30',
#  '',
#  '34',
#  '',
#  '14',
#  '',
#  '5',
#  '',
#  '24',
#  '',
#  '38',
#  '',
#  '37',
#  '',
#  '3',
#  '',
#  '27',
#  '',
#  '5',
#  '',
#  '42',
#  '',
#  '22',
#  '',
#  '40',
#  '',
#  '43',
#  '',
#  '34',
#  '',
#  '48',
#  '',
#  '47',
#  '',
#  '50']

# %%
#scraping weekson board

board_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]')
for i in board_tags[0:100]:
    board=i.text
    Weekson_board.append(board)
