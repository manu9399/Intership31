# %%
#Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release)
#and make data frame

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://www.scoopwhoop.com/entertainment/top-100-imdb-movies/"

# %%
r=requests.get("https://www.scoopwhoop.com/entertainment/top-100-imdb-movies/")
r
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(r.content)
htmlcontent=r.content

# %%
bs=BeautifulSoup(htmlcontent,'html.parser')
bs
# Out:
# <!DOCTYPE html>
# <html lang="en"> <head><meta charset="utf-8"/><meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/><meta content="ie=edge" http-equiv="X-UA-Compatible"/><meta content="286947471023-1gd3gh9mob8tslujirk4cbvgmg2eppr5.apps.googleusercontent.com" name="google-signin-client_id"/><meta content="110141895861579" property="fb:pages"/><meta content="w-5K8RO4qUtBEZjM1qwB_3Waul01CrTH0UV_pZGN7mg" name="google-site-verification"/><meta content="8677646C2CE716FE237A1E2DC9569AE8" name="msvalidate.01"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="ScoopWhoop" name="apple-mobile-web-app-title"/><script type="1b890dbaa8994596255ed452-text/javascript">var userAgent = navigator.userAgent.toLowerCase();
#    var Android = userAgent.indexOf("android") > -1;
#   if(!Android) {
#     document.getElementsByTagName('meta')["viewport"].content = "width=device-width, initial-scale=1";
# ...

# %%
name=[]
Ratings=[]

# %%
firstname=Soup.find('h2',class_="art-h2")
firstname.text
# Out:
# 'So we curated a list of the top 100 movies on\xa0IMDb\xa0and were wondering how many of those have you seen.'

# %%
for i in Soup.find_all('h2',class_="art-h2"):
    name.append(i.text)

# %%
for i in Soup.find_all('h2',class_="art-h2"):
    name.append(i.text)

# %%
name
# Out:
# ['So we curated a list of the top 100 movies on\xa0IMDb\xa0and were wondering how many of those have you seen.',
#  '1.\xa0The Shawshank Redemption (1994)',
#  'IMDb: 9.3\xa0',
#  '2. The Godfather (1972)',
#  'IMDb: 9.2',
#  '3.\xa0The Dark Knight (2008)',
#  'IMDb: 9.0',
#  '4.\xa0The Lord of the Rings: The Return of the King (2003)',
#  'IMDb: 9.0',
#  "5.\xa0Schindler's List (1993)",
#  'IMDb: 9.0',
#  '6.\xa0The Godfather: Part II (1974)',
#  'IMDb: 9.0',
#  '7.\xa0 12 Angry Men (1957)',
#  'IMDb: 9.0',
#  '8. Pulp Fiction (1994)',
#  'IMDb: 8.9',
#  '9. Inception (2010)',
#  'IMDb: 8.8',
#  '10.\xa0The Lord of the Rings: The Two Towers (2002)',
#  'IMDb: 8.8',
#  '11.\xa0Fight Club (1999) ',
#  'IMDb: 8.8',
#  '12.\xa0 The Lord of the Rings: The Fellowship of the Ring (2001)',
#  'IMDb: 8.8',
#  '13. Forrest Gump (1994) ',
#  'IMDb: 8.8',
#  '14. The Good, the Bad and the Ugly (1966)',
#  'IMDb: 8.8',
#  '15.\xa0The Matrix (1999)',
#  'IMDb: 8.7',
# ...

# %%
data=list(zip(name))
df=pd.DataFrame(data,columns=["name"])
df
# Out:
#                                                   name
# 0    So we curated a list of the top 100 movies on ...
# 1                   1. The Shawshank Redemption (1994)
# 2                                           IMDb: 9.3
# 3                              2. The Godfather (1972)
# 4                                            IMDb: 9.2
# ..                                                 ...
# 196                                          IMDb: 8.3
# 197                            99. Citizen Kane (1941)
# 198                                          IMDb: 8.3
# 199                                     100. M (1931)
# 200                                          IMDb: 8.3
#
# [201 rows x 1 columns]
