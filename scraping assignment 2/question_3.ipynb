# %%
import selenium
import pandas as pd 
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"F:\flip robo\chromedriver.exe")

# %%
driver.get("http://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
# using fliter selected location
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/section[1]/div[2]/div[5]/div[2]/div[3]/label/p/span[1]")
location.click()

# %%
# using fliter selected salary
salary=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]")
salary.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#scraping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#Scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
#scraping company name from the given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping experience_required from the given page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 "]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
#creating dataframe
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'experience_required':experience_required})
df
# Out:
#                                      job_title  \
# 0                               Data Scientist
# 1              DigitalBCG GAMMA Data Scientist
# 2                               Data Scientist
# 3          Data Scientist / Chat-bot Developer
# 4                          Lead Data Scientist
# 5        Data Scientist - Predictive Analytics
# 6   Data Scientist For Healthcare Product team
# 7            Data Scientist - Engine Algorithm
# 8                               Data Scientist
# 9                               Data Scientist
# 10                              Data Scientist
# 11             DigitalBCG GAMMA Data Scientist
# 12                              Data Scientist
# 13         Data Scientist / Chat-bot Developer
# 14                         Lead Data Scientist
# 15       Data Scientist - Predictive Analytics
# 16  Data Scientist For Healthcare Product team
# 17           Data Scientist - Engine Algorithm
# 18                              Data Scientist
# 19                              Data Scientist
#
#                                          job_location  \
# 0                                            8-10 Yrs
# 1                             3,00,000 - 4,50,000 PA.
# 2                  Noida, Nagpur, Bangalore/Bengaluru
# 3                                             2-5 Yrs
# 4                                       Not disclosed
# 5                      New Delhi, Bangalore/Bengaluru
# 6                                             2-7 Yrs
# 7                                       Not disclosed
# 8                                    Gurgaon/Gurugram
# 9                                             3-7 Yrs
# 10                 Noida, Nagpur, Bangalore/Bengaluru
# 11                     New Delhi, Bangalore/Bengaluru
# 12                                   Gurgaon/Gurugram
# 13  New Delhi, Bangalore/Bengaluru, Mumbai (All Ar...
# 14         Noida(Sector-59 Noida)\n(WFH during Covid)
# 15  Noida, Mumbai, Chandigarh, Hyderabad/Secundera...
# 16          Delhi / NCR, Chennai, Bangalore/Bengaluru
# 17  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 18                                   Gurgaon/Gurugram
# 19                                              Noida
#
#                 company_name                 experience_required
# 0                GlobalLogic                            8-10 Yrs
# 1    Boston Consulting Group             3,00,000 - 4,50,000 PA.
# 2                      Optum  Noida, Nagpur, Bangalore/Bengaluru
# 3               Big Seo Buzz                             2-5 Yrs
# 4    R Systems International                       Not disclosed
# 5               Confidential      New Delhi, Bangalore/Bengaluru
# 6   SECUREKLOUD TECHNOLOGIES                             2-7 Yrs
# 7               Primo Hiring                       Not disclosed
# 8             Feedback Infra                    Gurgaon/Gurugram
# 9                     4i Odc                             3-7 Yrs
# 10               GlobalLogic                            8-10 Yrs
# 11   Boston Consulting Group             3,00,000 - 4,50,000 PA.
# 12                     Optum  Noida, Nagpur, Bangalore/Bengaluru
# 13              Big Seo Buzz                             2-5 Yrs
# 14   R Systems International                       Not disclosed
# 15              Confidential      New Delhi, Bangalore/Bengaluru
# 16  SECUREKLOUD TECHNOLOGIES                             2-7 Yrs
# 17              Primo Hiring                       Not disclosed
# 18            Feedback Infra                    Gurgaon/Gurugram
# 19                    4i Odc                             3-7 Yrs
